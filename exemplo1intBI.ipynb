# %%
import pandas as pd
file_data = pd.read_csv('dadosCidades.csv') 
print(file_data)
num_of_records = len(file_data)
print(num_of_records)
# Out:
#           Cidade  Produção de Arroz 2020
# 0  Arroio Grande                  255129
# 1       Jaguarão                  168629
# 2

# %%
cidades = ['Arroio Grande', 'Jaguarão']
dados = [25129,168629]

# %% [markdown]
# A API Matplotlib possui uma função pie() cria um gráfico de pizza a partir dos dados de um array.

# %%
from matplotlib import pyplot as plt 
import numpy as np

# %%
fig = plt.figure(figsize =(10, 7)) 
plt.pie(dados, labels = cidades) 
plt.show()
